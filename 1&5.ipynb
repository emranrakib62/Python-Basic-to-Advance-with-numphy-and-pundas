# %% [markdown]
# <a href="https://colab.research.google.com/github/emranrakib62/Python-Basic-to-Advance-with-numphy-and-pundas/blob/main/1%265.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

categories=['A','B','C','D']
sizes=[23,56,96,36]

plt.bar(categories,sizes,color=['blue','green','red','yellow'])

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

categories=['A','B','C','D']
group1=[12,36,56,98]
group2=[15,25,63,96]

plt.bar(categories,group1,color='blue',label='group1')
plt.bar(categories,group2,color='green',bottom='group1',label='group2')


plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Chart Example')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data=np.random.randn(1000)
sns.kdeplot(data,shade=True,color='red')

plt.title("KDE Plot")
plt.show()
# Out:
# /tmp/ipython-input-2097235641.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data,shade=True,color='red')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns



df=sns.load_dataset("tips")
sns.swarmplot(x="day",y="total_bill",data=df,palette="coolwarm")

plt.title("Swarm plot")
plt.show()
# Out:
# /tmp/ipython-input-963209570.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill",data=df,palette="coolwarm")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df=sns.load_dataset("tips")

sns.regplot(x="total_bill",y="tip",data=df,scatter_kws={"color":"red"},line_kws={"color":"green"})

plt.title("Regration plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


labels=['Apple','Angur','komola','malta']
colors=['blue','green','red','black']
sizes=[36,45,89,63]

plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",startangle=140)

plt.title("pie chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


x=np.linspace(0,10,100)
y1=np.sin(x)
y2=np.cos(x)

plt.plot(x,y1,label='sine wave',color='blue')
plt.plot(x,y2,label='cosine wave',color='green')


plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple Line Plot')

plt.legend()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


df = sns.load_dataset("tips")


sns.violinplot(x="day", y="total_bill", data=df, palette="coolwarm")


plt.title('Violin Plot Example')
plt.show()
# Out:
# /tmp/ipython-input-17455356.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="total_bill", data=df, palette="coolwarm")

# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("/content/insurance.csv")


dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dataset['age'].value_counts()
# Out:
# age
# 18    69
# 19    68
# 46    29
# 52    29
# 50    29
# 47    29
# 48    29
# 51    29
# 45    29
# 20    29
# 24    28
# 27    28
# 28    28
# 25    28
# 23    28
# 49    28
# 54    28
# 53    28
# 22    28
# 21    28
# 26    28
# 31    27
# 41    27
# 44    27
# 43    27
# 42    27
# 29    27
# 30    27
# 40    27
# 32    26
# 33    26
# 57    26
# 34    26
# 55    26
# 56    26
# 35    25
# 58    25
# 37    25
# 59    25
# 39    25
# 36    25
# 38    25
# 62    23
# 60    23
# 63    23
# 61    23
# 64    22
# Name: count, dtype: int64

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


correlations = dataset.corr(numeric_only=True)
plt.figure(figsize = (20, 20))
sns.heatmap(correlations, annot=True, cmap='coolwarm')
plt.show()
